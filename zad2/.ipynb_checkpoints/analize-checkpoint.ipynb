# %%
import pandas as pd

# %%
df = pd.read_csv("results/experiment_results.csv")
print(df.to_string())
# Out:
#     activation optimizer        structure            dataset  mse_train  \
# 0         relu      Adam         [32, 32]  Dane1_standardise   0.194194
# 1         relu      Adam         [32, 32]          Dane1_raw   0.192496
# 2         relu      Adam         [32, 32]  Dane2_standardise   0.000488
# 3         relu      Adam         [32, 32]          Dane2_raw   0.000327
# 4         relu      Adam     [64, 64, 32]  Dane1_standardise   0.007434
# ..         ...       ...              ...                ...        ...
# 139       tanh       SGD   [128, 128, 64]          Dane2_raw   0.011584
# 140       tanh       SGD  [256, 256, 128]  Dane1_standardise   0.475067
# 141       tanh       SGD  [256, 256, 128]          Dane1_raw   0.018865
# 142       tanh       SGD  [256, 256, 128]  Dane2_standardise   0.001350
# 143       tanh       SGD  [256, 256, 128]          Dane2_raw   0.012511
#
#       mse_val  mse_test  epochs_run  fit_time_sec
# 0    0.163086  0.192150         143         22.22
# ...
